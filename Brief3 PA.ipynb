# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df_web = pd.read_excel (r'/Users/P.A/Documents/Simplon/DATA IA/Wine Spirit/web.xlsx')
print (df_web)
# Out:
#                       Sku  virtual  downloadable  rating_count  \
# 0     bon-cadeau-25-euros        0             0             0
# 1                   15298        0             0             0
# 2                   15296        0             0             0
# 3                   15300        0             0             0
# 4                   19814        0             0             0
# ...                   ...      ...           ...           ...
# 1508                16135        0             0             0
# 1509                15891        0             0             0
# 1510                15887        0             0             0
# 1511              13127-1        0             0             0
# 1512                16230        0             0             0
#
#       average_rating  total_sales tax_status  tax_class  post_author  \
# 0                0.0         10.0    taxable        NaN          1.0
# ...

# %%
df_web.describe()
# Out:
#        virtual  downloadable  rating_count  average_rating  total_sales  \
# count   1513.0        1513.0        1513.0          1430.0  1430.000000
# mean       0.0           0.0           0.0             0.0     4.006993
# std        0.0           0.0           0.0             0.0     8.510559
# min        0.0           0.0           0.0             0.0     0.000000
# 25%        0.0           0.0           0.0             0.0     0.000000
# 50%        0.0           0.0           0.0             0.0     1.000000
# 75%        0.0           0.0           0.0             0.0     4.000000
# max        0.0           0.0           0.0             0.0    96.000000
#
#        tax_class  post_author  post_content  post_password  \
# count        0.0  1430.000000           0.0            0.0
# mean         NaN     1.998601           NaN            NaN
# std          NaN     0.037385           NaN            NaN
# min          NaN     1.000000           NaN            NaN
# ...

# %%
df1_web = pd.read_excel("/Users/P.A/Documents/Simplon/DATA IA/Wine Spirit/web.xlsx") 
df2_liaison = pd.read_excel("/Users/P.A/Documents/Simplon/DATA IA/Wine Spirit/liaison.xlsx") 
df3_erp = pd.read_excel("/Users/P.A/Documents/Simplon/DATA IA/Wine Spirit/erp.xlsx")
# Out:
# /Users/P.A/opt/anaconda3/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df_merge1 = pd.merge(df3_erp, df2_liaison, left_on='product_id', right_on='product_id', how="inner")
print(df_merge1)
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status   id_web
# 0          3847           1   24.2               0   outofstock    15298
# 1          3849           1   34.3               0   outofstock    15296
# 2          3850           1   20.8               0   outofstock    15300
# 3          4032           1   14.1               0   outofstock    19814
# 4          4039           1   46.0               0   outofstock    19815
# ..          ...         ...    ...             ...          ...      ...
# 820        7203           0   45.0              30      instock      NaN
# 821        7204           0   45.0               9      instock      NaN
# 822        7247           1   54.8              23      instock  13127-1
# 823        7329           0   26.5              14      instock  14680-1
# 824        7338           1   16.3              45      instock    16230
#
# [825 rows x 6 columns]

# %%
df_merge2 = pd.merge(df_merge1, df_web, left_on='id_web', right_on='Sku', how="outer")
print(df_merge2)
# Out:
#       product_id  onsale_web  price  stock_quantity stock_status   id_web  \
# 0           3847           1   24.2               0   outofstock    15298
# 1           3847           1   24.2               0   outofstock    15298
# 2           3849           1   34.3               0   outofstock    15296
# 3           3849           1   34.3               0   outofstock    15296
# 4           3850           1   20.8               0   outofstock    15300
# ...          ...         ...    ...             ...          ...      ...
# 9178        7247           1   54.8              23      instock  13127-1
# 9179        7247           1   54.8              23      instock  13127-1
# 9180        7329           0   26.5              14      instock  14680-1
# 9181        7338           1   16.3              45      instock    16230
# 9182        7338           1   16.3              45      instock    16230
#
#           Sku  virtual  downloadable  rating_count  ...  \
# ...

# %%
df_merge2.drop(["virtual","downloadable","rating_count","average_rating","post_parent","menu_order","comment_count"], axis=1, inplace=True)
print(df_merge2)
# Out:
#       product_id  onsale_web  price  stock_quantity stock_status   id_web  \
# 0           3847           1   24.2               0   outofstock    15298
# 1           3847           1   24.2               0   outofstock    15298
# 2           3849           1   34.3               0   outofstock    15296
# 3           3849           1   34.3               0   outofstock    15296
# 4           3850           1   20.8               0   outofstock    15300
# ...          ...         ...    ...             ...          ...      ...
# 9178        7247           1   54.8              23      instock  13127-1
# 9179        7247           1   54.8              23      instock  13127-1
# 9180        7329           0   26.5              14      instock  14680-1
# 9181        7338           1   16.3              45      instock    16230
# 9182        7338           1   16.3              45      instock    16230
#
#           Sku  total_sales tax_status  tax_class  ...  comment_status  \
# ...

# %%
df_merge2.dropna(axis='columns', how='all').describe()
# Out:
#         product_id   onsale_web        price  stock_quantity  total_sales  \
# count  9183.000000  9183.000000  9183.000000     9183.000000  1610.000000
# mean   5963.138517     0.183273    33.756049       16.671785     3.559006
# std    1156.595743     0.386912    21.316980       30.931200     8.119252
# min    3847.000000     0.000000     5.200000        0.000000     0.000000
# 25%    4721.000000     0.000000    20.500000        0.000000     0.000000
# 50%    6567.000000     0.000000    30.500000        5.000000     0.000000
# 75%    7084.000000     0.000000    43.950000       21.000000     4.000000
# max    7338.000000     1.000000   225.000000      578.000000    96.000000
#
#        post_author
# count  1610.000000
# mean      1.998758
# std       0.035234
# min       1.000000
# 25%       2.000000
# 50%       2.000000
# 75%       2.000000
# max       2.000000

# %%
df_merge2 = df_merge2.drop_duplicates(subset='Sku')
df_merge2
# Out:
#       product_id  onsale_web  price  stock_quantity stock_status   id_web  \
# 0           3847           1   24.2               0   outofstock    15298
# 2           3849           1   34.3               0   outofstock    15296
# 4           3850           1   20.8               0   outofstock    15300
# 6           4032           1   14.1               0   outofstock    19814
# 8           4039           1   46.0               0   outofstock    19815
# ...          ...         ...    ...             ...          ...      ...
# 9172        6930           1    8.4              83      instock    16135
# 9174        7023           1   27.5              15      instock    15891
# 9176        7025           1   69.0               2      instock    15887
# 9178        7247           1   54.8              23      instock  13127-1
# 9181        7338           1   16.3              45      instock    16230
#
#           Sku  total_sales tax_status  tax_class  ...  comment_status  \
# ...

# %% [markdown]
# # Calcul CA/product

# %%
df_merge2["price"]*df_merge2["total_sales"]
# Out:
# 0       145.2
# 2         0.0
# 4         0.0
# 6        42.3
# 8         0.0
#         ...
# 9172     42.0
# 9174      0.0
# 9176      0.0
# 9178      0.0
# 9181      0.0
# Length: 715, dtype: float64

# %% [markdown]
# ## Calcul Total CA

# %%
(df_merge2["price"]*df_merge2["total_sales"]).sum()
# Out:
# 70568.6
